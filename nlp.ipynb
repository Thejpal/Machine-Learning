# %% [markdown]
# ## **Tokenization**
#
# Converts paragraphs to sentences or sentences to words. Here, both sentences and words can be tokens

# %%
import nltk

nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\raman\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk import word_tokenize, sent_tokenize

# %%
# Corpus - Also known as the text
# Tokens - Can be either words or sentences

random_para = "It was just a burger. Why couldn't she understand that? She knew he'd completely changed his life around her eating habits, so why couldn't she give him a break this one time? She wasn't even supposed to have found out. Yes, he had promised her and yes, he had broken that promise, but still in his mind, all it had been was just a burger."

# %% [markdown]
# ### **Sentence tokenization**
#
# * Converting a paragraph into a list of sentences

# %%
sent_tokenize(random_para)
# Out:
# ['It was just a burger.',
#  "Why couldn't she understand that?",
#  "She knew he'd completely changed his life around her eating habits, so why couldn't she give him a break this one time?",
#  "She wasn't even supposed to have found out.",
#  'Yes, he had promised her and yes, he had broken that promise, but still in his mind, all it had been was just a burger.']

# %% [markdown]
# ### **Word tokenization**
#
# * Converting a sentence or a paragraph into words

# %%
word_tokenize(random_para)
# Out:
# ['It',
#  'was',
#  'just',
#  'a',
#  'burger',
#  '.',
#  'Why',
#  'could',
#  "n't",
#  'she',
#  'understand',
#  'that',
#  '?',
#  'She',
#  'knew',
#  'he',
#  "'d",
#  'completely',
#  'changed',
#  'his',
#  'life',
#  'around',
#  'her',
#  'eating',
#  'habits',
#  ',',
#  'so',
#  'why',
#  'could',
#  "n't",
#  'she',
#  'give',
#  'him',
#  'a',
#  'break',
#  'this',
#  'one',
#  'time',
#  '?',
#  'She',
#  'was',
#  "n't",
#  'even',
#  'supposed',
#  'to',
#  'have',
#  'found',
#  'out',
#  '.',
#  'Yes',
#  ',',
#  'he',
#  'had',
#  'promised',
#  'her',
#  'and',
#  'yes',
#  ',',
#  'he',
#  'had',
#  'broken',
#  'that',
#  'promise',
#  ',',
#  'but',
#  'still',
#  'in',
#  'his',
#  'mind',
#  ',',
#  'all',
#  'it',
#  'had',
#  'been',
#  'was',
#  'just',
#  'a',
#  'burger',
#  '.']

# %% [markdown]
# ## **Stemming**
#
# Stemming is a process of converting a word to it's word stem by removing suffixes or prefixes

# %%
from nltk.stem import PorterStemmer, RegexpStemmer, SnowballStemmer

# %%
porter_stemmer = PorterStemmer()

# Removes the suffixes from the word based on the provided regular expression and $ symbol's position.
# If $ is not provided, it will remove the expression from both the start and end of the word.
# Min parameter specifies the length of the word required for the word to be stemmed.
regexp_stemmer = RegexpStemmer(regexp = "ing$|s$|es$|able$", min = 4)

# An advanced version of the Porter stemmer which also stems the words based on languages
snowball_stemmer = SnowballStemmer(language = "english")

# %%
words = ["running", "eating", "eats", "advisable", "fairly", "history", "writing", "eaten", "went", "goes", "gone", "sportingly", "congratulations"]

# %%
stemmed_words = [f"{word} ---> {porter_stemmer.stem(word)}, {regexp_stemmer.stem(word)}, {snowball_stemmer.stem(word)}" for word in words]

# %% [markdown]
# In stemming, the word we got as output is known as stem. Sometimes, the stem generated may not be a valid word or may have it's meaning altered. This is an issue even with advanced stemming techniques as demonstrated with the examples.

# %%
stemmed_words
# Out:
# ['running ---> run, runn, run',
#  'eating ---> eat, eat, eat',
#  'eats ---> eat, eat, eat',
#  'advisable ---> advis, advis, advis',
#  'fairly ---> fairli, fairly, fair',
#  'history ---> histori, history, histori',
#  'writing ---> write, writ, write',
#  'eaten ---> eaten, eaten, eaten',
#  'went ---> went, went, went',
#  'goes ---> goe, go, goe',
#  'gone ---> gone, gone, gone',
#  'sportingly ---> sportingli, sportingly, sport',
#  'congratulations ---> congratul, congratulation, congratul']

# %% [markdown]
# ### **Lemmatization**
#
# Lemmatization is similar to stemming. But rather than converting the word to it's stem like in stemming, it converts the word into it's root word or 'lemma'. The root word extracted during lemmatization is a valid and meaningful word. This technique overcomes the issue with stemming technique.

# %%
from nltk.stem import WordNetLemmatizer

# %%
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\raman\AppData\Roaming\nltk_data...
# True

# %%
lemmatizer = WordNetLemmatizer()

# %% [markdown]
# * Here, the lemmatize method takes in the word and parts of speech as parameters.
# * n - Noun
# * v - Verb
# * a - Adjectives
# * r - Adverb
# * s - Satellite Adjectives
# * This technique takes longer to execute than stemming as it looks through the entire wordnet database to find the root word but is more accurate.

# %%
lemmatized_words = [f'{word} ---> {lemmatizer.lemmatize(word, pos = "n")}, {lemmatizer.lemmatize(word, pos = "v")}, {lemmatizer.lemmatize(word, pos = "a")}, {lemmatizer.lemmatize(word, pos = "r")}, {lemmatizer.lemmatize(word, pos = "s")}' for word in words]

# %%
lemmatized_words
# Out:
# ['running ---> running, run, running, running, running',
#  'eating ---> eating, eat, eating, eating, eating',
#  'eats ---> eats, eat, eats, eats, eats',
#  'advisable ---> advisable, advisable, advisable, advisable, advisable',
#  'fairly ---> fairly, fairly, fairly, fairly, fairly',
#  'history ---> history, history, history, history, history',
#  'writing ---> writing, write, writing, writing, writing',
#  'eaten ---> eaten, eat, eaten, eaten, eaten',
#  'went ---> went, go, went, went, went',
#  'goes ---> go, go, goes, goes, goes',
#  'gone ---> gone, go, gone, gone, gone',
#  'sportingly ---> sportingly, sportingly, sportingly, sportingly, sportingly',
#  'congratulations ---> congratulation, congratulations, congratulations, congratulations, congratulations']

# %% [markdown]
# ## **Stop words**
#
# Words that don't contribute much to understand the meaning or intent of a given sentence are called stop words.

# %%
from nltk.corpus import stopwords

nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\raman\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
stopwords.words("english")
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
speech = """
My beloved citizens... No, my fellow Imanity.

We Imanity live in a world where war is forbidden by the ten pledges, yet we've lost again and again. And now all we have left is Elkia, our last city. So I ask you now: Why is this? Is it because the last king failed? Because we are the lowest ranked race? Because we can't use magic? Because we are fated to die, helpless?

No! In the ancient war, the gods, the elves, the warbeasts, all the races fought, and we fought among them and survived! Why is it that this whole continent was once ruled by humans? Is it because we are a race that specializes in violence? We can't use magic like the elves, nor are we physically strong like the warbeasts, nor do we have the longevity of the Flugel. Why were we able to rule the continent? Is it because we were masters of war?

I tell you it is not! We fought and survived because we are weak! In every time, in every world, the strong polish their fangs while the weak polish their wisdom. Why are we in such danger now? Because the ten pledges have broken the fangs of the strong, and they have learned to polish their wisdom. The wisdom and strategies that we, the weak, once monopolized... The power to survive... The strong have gained them all! And that brought us to this state!

Answer me this, everyone! Why do you bow your heads? I repeat, why do you bow your heads? We are the weak! We are the weak, just as we have always been! Yes, nothing has changed at all! The strong may imitate our weapons, but they will never master them! Because at the heart of our weapons lies a cowardice born of almost humiliating weakness. This cowardice has given us the wisdom to escape from magic. This cowardice has given us the wisdom, born from learning and experience, to predict the future itself! I say a third time. We are the weak! We are the proud weak who have, throughout history, torn out the throats of those who sit back and boast of their strength!

We declare now that we, as Elkia's 205th king... *And queen...* **... have taken the throne!** We hereby declare that we will live as the weak, fight as the weak, and as the weak, we will destroy the strong! As we once were, and as we will always be. Accept the fact that we are the weakest race. Accept that we are the weakest race, one that can become anything because we were born with nothing!

Now, let's begin the game. You've suffered enough, haven't you? You've endured enough humiliation, right? The wait is over, my fellow Imanity. As of this moment, my country, Elkia, declares war... on every other country in the world. Let slip the dogs of war! We're taking back our borders!
"""

# %%
sentences = sent_tokenize(speech)

# %%
sentences
# Out:
# ['\nMy beloved citizens... No, my fellow Imanity.',
#  "We Imanity live in a world where war is forbidden by the ten pledges, yet we've lost again and again.",
#  'And now all we have left is Elkia, our last city.',
#  'So I ask you now: Why is this?',
#  'Is it because the last king failed?',
#  'Because we are the lowest ranked race?',
#  "Because we can't use magic?",
#  'Because we are fated to die, helpless?',
#  'No!',
#  'In the ancient war, the gods, the elves, the warbeasts, all the races fought, and we fought among them and survived!',
#  'Why is it that this whole continent was once ruled by humans?',
#  'Is it because we are a race that specializes in violence?',
#  "We can't use magic like the elves, nor are we physically strong like the warbeasts, nor do we have the longevity of the Flugel.",
#  'Why were we able to rule the continent?',
#  'Is it because we were masters of war?',
#  'I tell you it is not!',
#  'We fought and survived because we are weak!',
# ...

# %%
stemmed_sentences = []

for sentence in sentences:
    # Tokenize the sentence into words
    words = word_tokenize(sentence)
    # Stem the tokenized words only if they are not stop words
    stemmed_speech_words = [snowball_stemmer.stem(word) for word in words if word not in stopwords.words("english")]
    # Join the stemmed words back into a sentence
    stemmed_sentences.append(" ".join(stemmed_speech_words))

# %%
stemmed_sentences
# Out:
# ['my belov citizen ... no , fellow iman .',
#  'we iman live world war forbidden ten pledg , yet ve lost .',
#  'and left elkia , last citi .',
#  'so i ask : whi ?',
#  'is last king fail ?',
#  'becaus lowest rank race ?',
#  "becaus ca n't use magic ?",
#  'becaus fate die , helpless ?',
#  'no !',
#  'in ancient war , god , elv , warbeast , race fought , fought among surviv !',
#  'whi whole contin rule human ?',
#  'is race special violenc ?',
#  "we ca n't use magic like elv , physic strong like warbeast , longev flugel .",
#  'whi abl rule contin ?',
#  'is master war ?',
#  'i tell !',
#  'we fought surviv weak !',
#  'in everi time , everi world , strong polish fang weak polish wisdom .',
#  'whi danger ?',
#  'becaus ten pledg broken fang strong , learn polish wisdom .',
#  'the wisdom strategi , weak , monopol ...',
#  'the power surviv ...',
#  'the strong gain !',
#  'and brought us state !',
#  'answer , everyon !',
#  'whi bow head ?',
#  'i repeat , bow head ?',
# ...

# %%
lemmatized_sentences = []

for sentence in sentences:
    # Tokenize the sentence into words
    words = word_tokenize(sentence)
    # StLemmatizeem the tokenized words only if they are not stop words
    lemmatized_speech_words = [lemmatizer.lemmatize(word, pos = "v") for word in words if word not in stopwords.words("english")]
    # Join the Lemmatize words back into a sentence
    lemmatized_sentences.append(" ".join(lemmatized_speech_words))

# %%
lemmatized_sentences
# Out:
# ['My beloved citizens ... No , fellow Imanity .',
#  "We Imanity live world war forbid ten pledge , yet 've lose .",
#  'And leave Elkia , last city .',
#  'So I ask : Why ?',
#  'Is last king fail ?',
#  'Because lowest rank race ?',
#  "Because ca n't use magic ?",
#  'Because fat die , helpless ?',
#  'No !',
#  'In ancient war , gods , elves , warbeasts , race fight , fight among survive !',
#  'Why whole continent rule humans ?',
#  'Is race specialize violence ?',
#  "We ca n't use magic like elves , physically strong like warbeasts , longevity Flugel .",
#  'Why able rule continent ?',
#  'Is master war ?',
#  'I tell !',
#  'We fight survive weak !',
#  'In every time , every world , strong polish fangs weak polish wisdom .',
#  'Why danger ?',
#  'Because ten pledge break fangs strong , learn polish wisdom .',
#  'The wisdom strategies , weak , monopolize ...',
#  'The power survive ...',
#  'The strong gain !',
#  'And bring us state !',
#  'Answer , everyone !',
# ...

# %% [markdown]
# ### **Parts of speech tagging**
#
# Tag each word to it's parts of speech

# %%
from nltk import pos_tag

nltk.download("averaged_perceptron_tagger")
nltk.download("averaged_perceptron_tagger_eng")
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\raman\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\raman\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
for sentence in sentences:
    words = word_tokenize(sentence)
    print(pos_tag(words))
# Out:
# [('My', 'PRP$'), ('beloved', 'JJ'), ('citizens', 'NNS'), ('...', ':'), ('No', 'RB'), (',', ','), ('my', 'PRP$'), ('fellow', 'JJ'), ('Imanity', 'NNP'), ('.', '.')]
# [('We', 'PRP'), ('Imanity', 'NNP'), ('live', 'VBP'), ('in', 'IN'), ('a', 'DT'), ('world', 'NN'), ('where', 'WRB'), ('war', 'NN'), ('is', 'VBZ'), ('forbidden', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('ten', 'NN'), ('pledges', 'VBZ'), (',', ','), ('yet', 'RB'), ('we', 'PRP'), ("'ve", 'VBP'), ('lost', 'VBN'), ('again', 'RB'), ('and', 'CC'), ('again', 'RB'), ('.', '.')]
# [('And', 'CC'), ('now', 'RB'), ('all', 'DT'), ('we', 'PRP'), ('have', 'VBP'), ('left', 'VBN'), ('is', 'VBZ'), ('Elkia', 'NNP'), (',', ','), ('our', 'PRP$'), ('last', 'JJ'), ('city', 'NN'), ('.', '.')]
# [('So', 'RB'), ('I', 'PRP'), ('ask', 'VBP'), ('you', 'PRP'), ('now', 'RB'), (':', ':'), ('Why', 'WRB'), ('is', 'VBZ'), ('this', 'DT'), ('?', '.')]
# ...
